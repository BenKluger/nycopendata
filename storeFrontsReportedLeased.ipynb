# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot

# %%
storeFronts = pd.read_csv('./csv/Storefronts_Reported_Leased_or_Not_Leased.csv')

# %%
storeFronts
# Out:
#        BOROUGH-BLOCK-LOT PROPERTY STREET ADDRESS OR STOREFRONT ADDRESS  \
# 0             1000010010                            1 GOVERNORS ISLAND
# 1             1000050010                              115 BROAD STREET
# 2             1000050010                              115 BROAD STREET
# 3             1000050010                              115 BROAD STREET
# 4             1000050010                              115 BROAD STREET
# ...                  ...                                           ...
# 75245         5080470031                               227 MAIN STREET
# 75246         5080470031                               225 MAIN STREET
# 75247         5080480075                               236 MAIN STREET
# 75248         5080480075                               236 MAIN STREET
# 75249         5080480075                               236 MAIN STREET
#
#              BOROUGH  ZIP CODE SOLD DATE LEASED ON 12/31  \
# ...

# %%
storeFronts.shape
# Out:
# (75250, 8)

# %%
storeFronts.dtypes
# Out:
# BOROUGH-BLOCK-LOT                                 int64
# PROPERTY STREET ADDRESS OR STOREFRONT ADDRESS    object
# BOROUGH                                          object
# ZIP CODE                                          int64
# SOLD DATE                                        object
# LEASED ON 12/31                                  object
# LEASED ON 6/30 OR DATE SOLD IF EARLIER           object
# PRIMARY BUSINESS ACTIVITY                        object
# dtype: object

# %%
storeFronts.sort_values(by='BOROUGH-BLOCK-LOT').head(100) #first 20 rows of the dataset by borough-block-lot
# Out:
#     BOROUGH-BLOCK-LOT PROPERTY STREET ADDRESS OR STOREFRONT ADDRESS  \
# 0          1000010010                            1 GOVERNORS ISLAND
# 1          1000050010                              115 BROAD STREET
# 2          1000050010                              115 BROAD STREET
# 3          1000050010                              115 BROAD STREET
# 4          1000050010                              115 BROAD STREET
# ..                ...                                           ...
# 95         1000160150                              250 VESEY STREET
# 96         1000160150                              250 VESEY STREET
# 97         1000160210                           399 CHAMBERS STREET
# 98         1000160210                           399 CHAMBERS STREET
# 99         1000160221                          450 NORTH END AVENUE
#
#       BOROUGH  ZIP CODE SOLD DATE LEASED ON 12/31  \
# 0   MANHATTAN     10004       NaN              NO
# ...

# %%
storeFronts['LEASED ON 12/31'].value_counts()
# Out:
# YES    63661
# NO     11589
# Name: LEASED ON 12/31, dtype: int64

# %%
storeFronts['LEASED ON 12/31'].value_counts('YES')
# Out:
# YES    0.845993
# NO     0.154007
# Name: LEASED ON 12/31, dtype: float64

# %%
storeFronts['LEASED ON 12/31'].value_counts('YES').plot.pie()
