# %%
import pandas as pd
import matplotlib.pyplot

# %%
storeFronts = pd.read_csv('./csv/Storefronts_Reported_Leased_or_Not_Leased.csv')

# %%
storeFronts
# Out:
#        BOROUGH-BLOCK-LOT PROPERTY STREET ADDRESS OR STOREFRONT ADDRESS  \
# 0             1000010010                            1 GOVERNORS ISLAND
# 1             1000050010                              115 BROAD STREET
# 2             1000050010                              115 BROAD STREET
# 3             1000050010                              115 BROAD STREET
# 4             1000050010                              115 BROAD STREET
# ...                  ...                                           ...
# 75245         5080470031                               227 MAIN STREET
# 75246         5080470031                               225 MAIN STREET
# 75247         5080480075                               236 MAIN STREET
# 75248         5080480075                               236 MAIN STREET
# 75249         5080480075                               236 MAIN STREET
#
#              BOROUGH  ZIP CODE SOLD DATE LEASED ON 12/31  \
# ...
